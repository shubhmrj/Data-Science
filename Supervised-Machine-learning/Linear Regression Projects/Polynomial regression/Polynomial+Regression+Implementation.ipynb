# %%
##import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X = 6 * np.random.rand(100, 1) - 3
y =0.5 * X**2 + 1.5*X + 2 + np.random.randn(100, 1)

# %%
X
# Out:
# array([[-2.11394621],
#        [-2.67682903],
#        [ 0.75972922],
#        [ 1.13886391],
#        [-0.21617848],
#        [ 0.78601919],
#        [ 0.61061976],
#        [-2.64644612],
#        [-0.77652445],
#        [-2.87737825],
#        [-0.30800735],
#        [-2.71466691],
#        [ 1.3697196 ],
#        [ 2.17737591],
#        [-1.48481781],
#        [-2.12268259],
#        [-1.54145215],
#        [-0.87599445],
#        [-1.88662074],
#        [-0.17408522],
#        [-1.60337447],
#        [ 0.76537055],
#        [ 0.5143249 ],
#        [ 1.15962839],
#        [ 0.22623213],
#        [-0.97547786],
#        [-2.04344424],
#        [-0.38483018],
#        [-1.63874241],
#        [-1.49530413],
#        [-1.32006495],
#        [-0.33215821],
#        [-1.30160444],
#        [-2.2822023 ],
#        [ 2.05437795],
#        [-2.27166229],
#        [-1.24392562],
#        [-2.00917056],
#        [-1.33199547],
#        [-2.05267482],
#        [ 0.77275173],
#        [-1.48401435],
#        [ 0.37202178],
#        [ 0.47557596],
#        [-2.20568375],
#        [ 0.5704883 ],
#        [ 1.04222282],
#        [-0.89836409],
#        [-0.86190256],
#        [-1.0704142 ],
#        [-1.12345876],
#        [ 1.85021595],
#        [ 2.5453164 ],
#        [-0.77553302],
#        [-2.1697886 ],
#        [-0.60116035],
#        [-0.25844202],
#        [-1.14363936],
#        [-0.17707951],
#        [ 0.77990539],
#        [-2.41679411],
#        [-0.9458625 ],
#        [ 1.23416959],
#        [ 2.16838885],
#        [-1.62261357],
#        [-2.26837342],
#        [ 2.66171776],
#        [ 1.09325174],
#        [ 1.06162554],
#        [ 2.59100959],
#        [ 1.38813989],
#        [ 2.81868108],
#        [ 2.96147616],
#        [-2.46647583],
#        [ 1.97537529],
#        [-1.14407951],
#        [ 0.34963367],
#        [ 0.52580233],
#        [ 0.32187779],
#        [-2.88667044],
#        [ 0.76167491],
#        [ 0.2957323 ],
#        [-1.85805525],
#        [-2.94401085],
#        [ 0.14919818],
#        [ 0.88598022],
#        [ 1.86984598],
#        [-0.1588754 ],
#        [-2.51714599],
#        [-0.34876421],
#        [-0.47873647],
#        [-0.32732645],
#        [ 0.68174334],
#        [ 0.98103506],
#        [-2.01660073],
#        [-2.52983524],
#        [-2.99790063],
#        [ 0.9542731 ],
#        [-0.87594059],
#        [-2.47558541]])

# %%
y
# Out:
# array([[-0.51815605],
#        [ 1.42503226],
#        [ 2.23215222],
#        [ 3.46492935],
#        [ 1.75855618],
#        [ 2.15559374],
#        [ 1.92830077],
#        [ 1.37906207],
#        [ 0.79529317],
#        [ 0.94746747],
#        [ 3.3382087 ],
#        [ 2.92466766],
#        [ 6.11892587],
#        [ 5.4110571 ],
#        [-0.23951783],
#        [ 0.35333447],
#        [ 0.26316429],
#        [ 0.62117369],
#        [ 1.53339162],
#        [ 0.6417127 ],
#        [-0.11372768],
#        [ 1.40184356],
#        [ 2.73670045],
#        [ 5.03216718],
#        [ 2.32210345],
#        [ 0.76904052],
#        [ 1.22557583],
#        [ 2.17109327],
#        [ 1.23187885],
#        [ 0.70202988],
#        [-0.31276685],
#        [ 1.97970676],
#        [ 0.35330714],
#        [ 0.09475969],
#        [ 7.78993674],
#        [ 1.02945496],
#        [ 1.16951206],
#        [ 2.01383018],
#        [-0.83979624],
#        [ 2.26938915],
#        [ 2.58353132],
#        [ 1.16712641],
#        [ 3.14649517],
#        [ 1.6590508 ],
#        [ 2.05526004],
#        [ 2.55323468],
#        [ 4.03614908],
#        [ 2.02202777],
#        [ 1.00865872],
#        [-0.36247262],
#        [-1.24939851],
#        [ 7.18263213],
#        [ 8.30821428],
#        [-1.38137074],
#        [ 1.08557845],
#        [ 3.52756391],
#        [ 2.00165062],
#        [ 1.94143817],
#        [ 1.92326966],
#        [ 5.11239403],
#        [ 2.45893278],
#        [ 0.47817469],
#        [ 3.15611144],
#        [ 7.8987057 ],
#        [ 3.2365783 ],
#        [ 1.37850407],
#        [11.25221176],
#        [ 4.1827064 ],
#        [ 2.23483136],
#        [ 9.84236394],
#        [ 4.02940471],
#        [11.06480904],
#        [11.45952264],
#        [ 1.77628374],
#        [ 6.79035305],
#        [ 1.49922499],
#        [ 4.25956487],
#        [ 0.98964032],
#        [ 3.1215148 ],
#        [ 1.80940792],
#        [ 1.41437543],
#        [ 2.87639529],
#        [ 2.26125307],
#        [ 2.38322685],
#        [ 2.03266967],
#        [ 2.98242144],
#        [ 7.51676473],
#        [ 4.10163325],
#        [ 0.43096458],
#        [ 1.69839571],
#        [ 2.102873  ],
#        [ 2.23309425],
#        [ 2.610086  ],
#        [ 4.67448208],
#        [ 1.6672328 ],
#        [ 2.11543412],
#        [ 1.82590914],
#        [ 5.30301411],
#        [ 1.98173633],
#        [ 0.90274273]])

# %%
plt.plot(X,y,'b.')

# %%
plt.plot(X,y,'-o')
plt.xlabel('X dataset')
plt.ylabel('Y dataset')
# Out:
# Text(0, 0.5, 'Y dataset')

# %%
X = 6 * np.random.rand(100, 1) - 3
y =0.5 * X**2 + 1.5*X + 2 + np.random.randn(100, 1)
# quadratic equation used- y=0.5x^2+1.5x+2+outliers
plt.scatter(X,y,color='g')
plt.xlabel('X dataset')
plt.ylabel('Y dataset')
# Out:
# Text(0, 0.5, 'Y dataset')

# %% [markdown]
# First try to on Train Linear regression

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
## Lets implement Simple Linear Regression
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_train
# Out:
# array([[ 2.99466654],
#        [ 1.68245411],
#        [-0.21970742],
#        [ 1.93370849],
#        [-1.48253238],
#        [ 2.94484843],
#        [ 0.99089996],
#        [ 0.72921893],
#        [-2.20751528],
#        [ 1.44169495],
#        [-2.44565461],
#        [ 2.34484386],
#        [-0.64724932],
#        [ 2.2456315 ],
#        [-1.0115518 ],
#        [ 1.23330381],
#        [-1.80826503],
#        [ 0.81155308],
#        [-2.75277196],
#        [-2.8689827 ],
#        [-2.19343599],
#        [-2.0270735 ],
#        [-0.21877308],
#        [ 2.07744631],
#        [-0.87166359],
#        [ 2.1629592 ],
#        [-2.70999116],
#        [ 1.25540447],
#        [-2.47126401],
#        [-1.31105946],
#        [-0.34636271],
#        [-0.2232162 ],
#        [-2.80878218],
#        [-2.79202005],
#        [-0.82380623],
#        [-2.92405959],
#        [-2.65223452],
#        [ 2.9637368 ],
#        [ 1.6030228 ],
#        [-2.64808916],
#        [-0.20814902],
#        [-1.8250542 ],
#        [ 2.02333767],
#        [ 0.67112609],
#        [ 0.10307405],
#        [-2.27349555],
#        [-2.83432732],
#        [-0.68098921],
#        [ 1.29627008],
#        [-2.45579514],
#        [ 1.77863001],
#        [ 1.32884617],
#        [ 0.87615805],
#        [ 2.84130011],
#        [ 2.46100994],
#        [ 0.11033941],
#        [-1.85341846],
#        [-1.65650182],
#        [ 1.73832508],
#        [ 1.80298052],
#        [-1.45502535],
#        [-2.55436035],
#        [-0.93442128],
#        [-2.29350558],
#        [-0.36220619],
#        [ 2.77665661],
#        [ 1.55037542],
#        [ 1.54019344],
#        [-2.21710361],
#        [-0.35440578],
#        [-2.52665707],
#        [ 0.11424118],
#        [ 0.57625544],
#        [-0.15268175],
#        [-1.75694258],
#        [ 0.53923342],
#        [-0.62834791],
#        [-2.64376136],
#        [-1.24553627],
#        [-2.51811164]])

# %%
y_train
# Out:
# array([[ 1.15217764e+01],
#        [ 6.43952888e+00],
#        [ 2.43868983e+00],
#        [ 7.82608504e+00],
#        [ 3.17685930e-01],
#        [ 1.14365986e+01],
#        [ 3.44559948e+00],
#        [ 1.07990853e+00],
#        [ 2.31955974e+00],
#        [ 6.24714167e+00],
#        [ 1.41159318e+00],
#        [ 8.77557115e+00],
#        [ 1.12848037e+00],
#        [ 8.71218454e+00],
#        [ 4.79331811e-01],
#        [ 5.29402482e+00],
#        [ 1.47411650e+00],
#        [ 5.23667651e+00],
#        [ 2.86266997e+00],
#        [ 3.25062234e+00],
#        [-6.40273564e-03],
#        [ 1.59160237e+00],
#        [ 1.62638685e+00],
#        [ 5.61114939e+00],
#        [-9.69956536e-01],
#        [ 7.97859574e+00],
#        [ 1.44902306e+00],
#        [ 3.15225585e+00],
#        [ 1.33538200e+00],
#        [ 3.20606471e-02],
#        [ 5.84052255e-01],
#        [ 8.02683639e-01],
#        [ 2.61661588e+00],
#        [ 3.15784930e+00],
#        [ 5.03647377e-01],
#        [ 1.50102162e+00],
#        [ 2.04741152e+00],
#        [ 1.09066453e+01],
#        [ 5.78113971e+00],
#        [ 1.57569627e+00],
#        [ 1.55457174e+00],
#        [ 1.38012941e+00],
#        [ 6.58574581e+00],
#        [ 3.51450796e+00],
#        [ 1.20728156e+00],
#        [ 3.77991907e-01],
#        [ 2.56476365e+00],
#        [ 1.01834727e+00],
#        [ 7.20162263e+00],
#        [ 6.15726325e-01],
#        [ 6.55924022e+00],
#        [ 6.37647562e+00],
#        [ 2.12198824e+00],
#        [ 1.05898943e+01],
#        [ 8.31548641e+00],
#        [ 2.28695186e+00],
#        [ 2.36951479e+00],
#        [ 1.58978797e+00],
#        [ 5.50400042e+00],
#        [ 5.37549286e+00],
#        [ 3.12855953e+00],
#        [-1.15692081e+00],
#        [ 5.47301380e-01],
#        [ 1.96640458e+00],
#        [ 2.05409406e+00],
#        [ 9.97975002e+00],
#        [ 5.92734862e+00],
#        [ 5.02128843e+00],
#        [ 2.01013437e-02],
#        [ 6.93086368e-01],
#        [ 2.14925985e+00],
#        [ 1.54218490e+00],
#        [ 1.66740441e+00],
#        [ 2.40355315e+00],
#        [ 2.04966995e+00],
#        [ 2.27265779e+00],
#        [ 1.69526508e+00],
#        [ 1.21265423e+00],
#        [ 1.94371591e+00],
#        [ 3.00739763e-01]])

# %%
model.coef_
# Out:
# array([[1.32829663]])

# %%
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
from sklearn import metrics
y_pred=model.predict(X_test)

# %%
mse=metrics.mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 1.7312808237399877

# %%
r_square=metrics.r2_score(y_test,y_pred)
print(r_square)
# Out:
# 0.7814662638659962

# %%
# from sklearn.metrics import mean_squared_error
# from sklearn.metrics import r2_score
# y_pred=model.predict(X_test)
# print(mean_squared_error(y_test,y_pred))
# print(r2_score(y_test,y_pred))

# %%
plt.plot(X_train,y_train,'b.')
plt.xlabel('X')
plt.ylabel('Y')
plt.Figure(figsize=(2,2))

# %%
plt.plot(X_train,y_train,'b.')
plt.plot(X_test,y_pred,'r')
plt.xlabel('X')
plt.ylabel('Y')
plt.Figure(figsize=(2,2))

# %%
## Lets visualize this model
plt.plot(X_train,model.predict(X_train),color='r')
plt.scatter(X_train,y_train)
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# so in the above diagram you can see there is difference between actual value and predicted value and also check best fit line

# %%
#LEts apply polynomial transformation
from sklearn  import preprocessing
poly=preprocessing.PolynomialFeatures(degree=2,include_bias=True)

# %%
X_train_poly=poly.fit_transform(X_train)

# %%
X_train_poly
# Out:
# array([[ 1.        ,  2.99466654,  8.96802769],
#        [ 1.        ,  1.68245411,  2.83065184],
#        [ 1.        , -0.21970742,  0.04827135],
#        [ 1.        ,  1.93370849,  3.73922851],
#        [ 1.        , -1.48253238,  2.19790224],
#        [ 1.        ,  2.94484843,  8.67213229],
#        [ 1.        ,  0.99089996,  0.98188272],
#        [ 1.        ,  0.72921893,  0.53176025],
#        [ 1.        , -2.20751528,  4.87312371],
#        [ 1.        ,  1.44169495,  2.07848434],
#        [ 1.        , -2.44565461,  5.98122646],
#        [ 1.        ,  2.34484386,  5.49829274],
#        [ 1.        , -0.64724932,  0.41893168],
#        [ 1.        ,  2.2456315 ,  5.04286085],
#        [ 1.        , -1.0115518 ,  1.02323704],
#        [ 1.        ,  1.23330381,  1.52103828],
#        [ 1.        , -1.80826503,  3.26982241],
#        [ 1.        ,  0.81155308,  0.65861841],
#        [ 1.        , -2.75277196,  7.57775347],
#        [ 1.        , -2.8689827 ,  8.2310617 ],
#        [ 1.        , -2.19343599,  4.81116143],
#        [ 1.        , -2.0270735 ,  4.10902699],
#        [ 1.        , -0.21877308,  0.04786166],
#        [ 1.        ,  2.07744631,  4.31578318],
#        [ 1.        , -0.87166359,  0.75979742],
#        [ 1.        ,  2.1629592 ,  4.67839251],
#        [ 1.        , -2.70999116,  7.3440521 ],
#        [ 1.        ,  1.25540447,  1.57604038],
#        [ 1.        , -2.47126401,  6.10714583],
#        [ 1.        , -1.31105946,  1.71887691],
#        [ 1.        , -0.34636271,  0.11996713],
#        [ 1.        , -0.2232162 ,  0.04982547],
#        [ 1.        , -2.80878218,  7.88925733],
#        [ 1.        , -2.79202005,  7.79537598],
#        [ 1.        , -0.82380623,  0.6786567 ],
#        [ 1.        , -2.92405959,  8.5501245 ],
#        [ 1.        , -2.65223452,  7.03434797],
#        [ 1.        ,  2.9637368 ,  8.78373579],
#        [ 1.        ,  1.6030228 ,  2.56968208],
#        [ 1.        , -2.64808916,  7.01237621],
#        [ 1.        , -0.20814902,  0.04332602],
#        [ 1.        , -1.8250542 ,  3.33082283],
#        [ 1.        ,  2.02333767,  4.09389532],
#        [ 1.        ,  0.67112609,  0.45041023],
#        [ 1.        ,  0.10307405,  0.01062426],
#        [ 1.        , -2.27349555,  5.168782  ],
#        [ 1.        , -2.83432732,  8.03341134],
#        [ 1.        , -0.68098921,  0.4637463 ],
#        [ 1.        ,  1.29627008,  1.68031612],
#        [ 1.        , -2.45579514,  6.03092975],
#        [ 1.        ,  1.77863001,  3.16352473],
#        [ 1.        ,  1.32884617,  1.76583215],
#        [ 1.        ,  0.87615805,  0.76765293],
#        [ 1.        ,  2.84130011,  8.07298629],
#        [ 1.        ,  2.46100994,  6.05656992],
#        [ 1.        ,  0.11033941,  0.01217478],
#        [ 1.        , -1.85341846,  3.43515998],
#        [ 1.        , -1.65650182,  2.74399828],
#        [ 1.        ,  1.73832508,  3.02177408],
#        [ 1.        ,  1.80298052,  3.25073877],
#        [ 1.        , -1.45502535,  2.11709876],
#        [ 1.        , -2.55436035,  6.5247568 ],
#        [ 1.        , -0.93442128,  0.87314313],
#        [ 1.        , -2.29350558,  5.26016785],
#        [ 1.        , -0.36220619,  0.13119332],
#        [ 1.        ,  2.77665661,  7.70982195],
#        [ 1.        ,  1.55037542,  2.40366393],
#        [ 1.        ,  1.54019344,  2.37219584],
#        [ 1.        , -2.21710361,  4.91554843],
#        [ 1.        , -0.35440578,  0.12560346],
#        [ 1.        , -2.52665707,  6.38399595],
#        [ 1.        ,  0.11424118,  0.01305105],
#        [ 1.        ,  0.57625544,  0.33207033],
#        [ 1.        , -0.15268175,  0.02331172],
#        [ 1.        , -1.75694258,  3.08684721],
#        [ 1.        ,  0.53923342,  0.29077268],
#        [ 1.        , -0.62834791,  0.3948211 ],
#        [ 1.        , -2.64376136,  6.98947415],
#        [ 1.        , -1.24553627,  1.55136061],
#        [ 1.        , -2.51811164,  6.34088622]])

# %%
X_test_poly=poly.transform(X_test)

# %%
X_test_poly
# Out:
# array([[ 1.        , -2.46765826,  6.08933727],
#        [ 1.        , -0.75479365,  0.56971345],
#        [ 1.        , -0.14024274,  0.01966803],
#        [ 1.        , -2.27853761,  5.19173366],
#        [ 1.        , -1.45817501,  2.12627435],
#        [ 1.        , -2.73490223,  7.47969019],
#        [ 1.        ,  1.17198539,  1.37354975],
#        [ 1.        ,  0.54781874,  0.30010538],
#        [ 1.        ,  1.77995819,  3.16825117],
#        [ 1.        ,  1.56589644,  2.45203167],
#        [ 1.        , -0.5255787 ,  0.27623297],
#        [ 1.        , -2.11890828,  4.4897723 ],
#        [ 1.        , -2.7264738 ,  7.4336594 ],
#        [ 1.        , -0.56971236,  0.32457218],
#        [ 1.        , -2.17507324,  4.73094358],
#        [ 1.        , -0.97770493,  0.95590692],
#        [ 1.        , -2.41693963,  5.84159716],
#        [ 1.        ,  2.53690852,  6.43590483],
#        [ 1.        ,  2.77431704,  7.69683502],
#        [ 1.        ,  2.20112122,  4.84493464]])

# %%
# previous score
r_square=metrics.r2_score(y_test,y_pred)
print(r_square)
# Out:
# 0.7814662638659962

# %%
from sklearn import metrics
regression=LinearRegression()
regression.fit(X_train_poly,y_train)

y_pred= regression.predict(X_test_poly)
r_square=metrics.r2_score(y_test,y_pred)
print(r_square)
# Out:
# 0.8875473321453684

# %%
print(regression.coef_)
# Out:
# [[0.         1.50038513 0.56301416]]

# %%
print(regression.intercept_)
# Out:
# [1.8082597]

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred)

# %%
poly=preprocessing.PolynomialFeatures(degree=3,include_bias=True)
X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test)

# %%
X_train_poly
# Out:
# array([[ 1.00000000e+00,  2.99466654e+00,  8.96802769e+00,
#          2.68562524e+01],
#        [ 1.00000000e+00,  1.68245411e+00,  2.83065184e+00,
#          4.76244182e+00],
#        [ 1.00000000e+00, -2.19707419e-01,  4.82713500e-02,
#         -1.06055737e-02],
#        [ 1.00000000e+00,  1.93370849e+00,  3.73922851e+00,
#          7.23057791e+00],
#        [ 1.00000000e+00, -1.48253238e+00,  2.19790224e+00,
#         -3.25846124e+00],
#        [ 1.00000000e+00,  2.94484843e+00,  8.67213229e+00,
#          2.55381152e+01],
#        [ 1.00000000e+00,  9.90899956e-01,  9.81882722e-01,
#          9.72947546e-01],
#        [ 1.00000000e+00,  7.29218930e-01,  5.31760247e-01,
#          3.87769638e-01],
#        [ 1.00000000e+00, -2.20751528e+00,  4.87312371e+00,
#         -1.07574950e+01],
#        [ 1.00000000e+00,  1.44169495e+00,  2.07848434e+00,
#          2.99654038e+00],
#        [ 1.00000000e+00, -2.44565461e+00,  5.98122646e+00,
#         -1.46280141e+01],
#        [ 1.00000000e+00,  2.34484386e+00,  5.49829274e+00,
#          1.28926380e+01],
#        [ 1.00000000e+00, -6.47249322e-01,  4.18931684e-01,
#         -2.71153248e-01],
#        [ 1.00000000e+00,  2.24563150e+00,  5.04286085e+00,
#          1.13244072e+01],
#        [ 1.00000000e+00, -1.01155180e+00,  1.02323704e+00,
#         -1.03505727e+00],
#        [ 1.00000000e+00,  1.23330381e+00,  1.52103828e+00,
#          1.87590230e+00],
#        [ 1.00000000e+00, -1.80826503e+00,  3.26982241e+00,
#         -5.91270550e+00],
#        [ 1.00000000e+00,  8.11553084e-01,  6.58618408e-01,
#          5.34503800e-01],
#        [ 1.00000000e+00, -2.75277196e+00,  7.57775347e+00,
#         -2.08598273e+01],
#        [ 1.00000000e+00, -2.86898270e+00,  8.23106170e+00,
#         -2.36147736e+01],
#        [ 1.00000000e+00, -2.19343599e+00,  4.81116143e+00,
#         -1.05529746e+01],
#        [ 1.00000000e+00, -2.02707350e+00,  4.10902699e+00,
#         -8.32929975e+00],
#        [ 1.00000000e+00, -2.18773078e-01,  4.78616597e-02,
#         -1.04708426e-02],
-01],
#        [ 1.00000000e+00,  9.79899497e-01,  9.60203025e-01,
#          9.40902462e-01],
#        [ 1.00000000e+00,  1.01005025e+00,  1.02020151e+00,
#          1.03045479e+00],
#        [ 1.00000000e+00,  1.04020101e+00,  1.08201813e+00,
#          1.12551635e+00],
#        [ 1.00000000e+00,  1.07035176e+00,  1.14565289e+00,
#          1.22625158e+00],
#        [ 1.00000000e+00,  1.10050251e+00,  1.21110578e+00,
#          1.33282495e+00],
#        [ 1.00000000e+00,  1.13065327e+00,  1.27837681e+00,
#          1.44540091e+00],
#        [ 1.00000000e+00,  1.16080402e+00,  1.34746597e+00,
#          1.56414392e+00],
#        [ 1.00000000e+00,  1.19095477e+00,  1.41837327e+00,
#          1.68921842e+00],
#        [ 1.00000000e+00,  1.22110553e+00,  1.49109871e+00,
#          1.82078888e+00],
#        [ 1.00000000e+00,  1.25125628e+00,  1.56564228e+00,
#          1.95901974e+00],
#        [ 1.00000000e+00,  1.28140704e+00,  1.64200399e+00,
#          2.10407546e+00],
#        [ 1.00000000e+00,  1.31155779e+00,  1.72018383e+00,
#          2.25612051e+00],
#        [ 1.00000000e+00,  1.34170854e+00,  1.80018181e+00,
#          2.41531932e+00],
#        [ 1.00000000e+00,  1.37185930e+00,  1.88199793e+00,
#          2.58183636e+00],
#        [ 1.00000000e+00,  1.40201005e+00,  1.96563218e+00,
#          2.75583607e+00],
#        [ 1.00000000e+00,  1.43216080e+00,  2.05108457e+00,
#          2.93748292e+00],
#        [ 1.00000000e+00,  1.46231156e+00,  2.13835509e+00,
#          3.12694137e+00],
#        [ 1.00000000e+00,  1.49246231e+00,  2.22744375e+00,
#          3.32437585e+00],
#        [ 1.00000000e+00,  1.52261307e+00,  2.31835055e+00,
#          3.52995083e+00],
#        [ 1.00000000e+00,  1.55276382e+00,  2.41107548e+00,
#          3.74383077e+00],
#        [ 1.00000000e+00,  1.58291457e+00,  2.50561854e+00,
#          3.96618011e+00],
#        [ 1.00000000e+00,  1.61306533e+00,  2.60197975e+00,
#          4.19716331e+00],
#        [ 1.00000000e+00,  1.64321608e+00,  2.70015909e+00,
#          4.43694483e+00],
#        [ 1.00000000e+00,  1.67336683e+00,  2.80015656e+00,
#          4.68568912e+00],
#        [ 1.00000000e+00,  1.70351759e+00,  2.90197217e+00,
#          4.94356064e+00],
#        [ 1.00000000e+00,  1.73366834e+00,  3.00560592e+00,
#          5.21072383e+00],
#        [ 1.00000000e+00,  1.76381910e+00,  3.11105780e+00,
#          5.48734316e+00],
#        [ 1.00000000e+00,  1.79396985e+00,  3.21832782e+00,
#          5.77358307e+00],
#        [ 1.00000000e+00,  1.82412060e+00,  3.32741597e+00,
#          6.06960803e+00],
#        [ 1.00000000e+00,  1.85427136e+00,  3.43832226e+00,
#          6.37558249e+00],
#        [ 1.00000000e+00,  1.88442211e+00,  3.55104669e+00,
#          6.69167090e+00],
#        [ 1.00000000e+00,  1.91457286e+00,  3.66558925e+00,
#          7.01803772e+00],
#        [ 1.00000000e+00,  1.94472362e+00,  3.78194995e+00,
#          7.35484739e+00],
#        [ 1.00000000e+00,  1.97487437e+00,  3.90012878e+00,
#          7.70226438e+00],
#        [ 1.00000000e+00,  2.00502513e+00,  4.02012575e+00,
#          8.06045315e+00],
#        [ 1.00000000e+00,  2.03517588e+00,  4.14194086e+00,
#          8.42957813e+00],
#        [ 1.00000000e+00,  2.06532663e+00,  4.26557410e+00,
#          8.80980380e+00],
#        [ 1.00000000e+00,  2.09547739e+00,  4.39102548e+00,
#          9.20129460e+00],
#        [ 1.00000000e+00,  2.12562814e+00,  4.51829499e+00,
#          9.60421498e+00],
#        [ 1.00000000e+00,  2.15577889e+00,  4.64738264e+00,
#          1.00187294e+01],
#        [ 1.00000000e+00,  2.18592965e+00,  4.77828843e+00,
#          1.04450023e+01],
#        [ 1.00000000e+00,  2.21608040e+00,  4.91101235e+00,
#          1.08831982e+01],
#        [ 1.00000000e+00,  2.24623116e+00,  5.04555441e+00,
#          1.13334815e+01],
#        [ 1.00000000e+00,  2.27638191e+00,  5.18191460e+00,
#          1.17960166e+01],
#        [ 1.00000000e+00,  2.30653266e+00,  5.32009293e+00,
#          1.22709681e+01],
#        [ 1.00000000e+00,  2.33668342e+00,  5.46008939e+00,
#          1.27585003e+01],
#        [ 1.00000000e+00,  2.36683417e+00,  5.60190399e+00,
#          1.32587778e+01],
#        [ 1.00000000e+00,  2.39698492e+00,  5.74553673e+00,
#          1.37719649e+01],
#        [ 1.00000000e+00,  2.42713568e+00,  5.89098760e+00,
#          1.42982262e+01],
#        [ 1.00000000e+00,  2.45728643e+00,  6.03825661e+00,
#          1.48377260e+01],
#        [ 1.00000000e+00,  2.48743719e+00,  6.18734375e+00,
#          1.53906289e+01],
#        [ 1.00000000e+00,  2.51758794e+00,  6.33824903e+00,
#          1.59570993e+01],
#        [ 1.00000000e+00,  2.54773869e+00,  6.49097245e+00,
#          1.65373017e+01],
#        [ 1.00000000e+00,  2.57788945e+00,  6.64551400e+00,
#          1.71314004e+01],
#        [ 1.00000000e+00,  2.60804020e+00,  6.80187369e+00,
#          1.77395600e+01],
#        [ 1.00000000e+00,  2.63819095e+00,  6.96005151e+00,
#          1.83619449e+01],
#        [ 1.00000000e+00,  2.66834171e+00,  7.12004747e+00,
#          1.89987196e+01],
#        [ 1.00000000e+00,  2.69849246e+00,  7.28186157e+00,
#          1.96500486e+01],
#        [ 1.00000000e+00,  2.72864322e+00,  7.44549380e+00,
#          2.03160961e+01],
#        [ 1.00000000e+00,  2.75879397e+00,  7.61094417e+00,
#          2.09970269e+01],
#        [ 1.00000000e+00,  2.78894472e+00,  7.77821267e+00,
#          2.16930052e+01],
#        [ 1.00000000e+00,  2.81909548e+00,  7.94729931e+00,
#          2.24041955e+01],
#        [ 1.00000000e+00,  2.84924623e+00,  8.11820409e+00,
#          2.31307624e+01],
#        [ 1.00000000e+00,  2.87939698e+00,  8.29092700e+00,
#          2.38728702e+01],
#        [ 1.00000000e+00,  2.90954774e+00,  8.46546804e+00,
#          2.46306834e+01],
#        [ 1.00000000e+00,  2.93969849e+00,  8.64182723e+00,
#          2.54043665e+01],
#        [ 1.00000000e+00,  2.96984925e+00,  8.82000455e+00,
#          2.61940839e+01],
#        [ 1.00000000e+00,  3.00000000e+00,  9.00000000e+00,
#          2.70000000e+01]])

# %%
y_new = regression.predict(X_new_poly)
plt.plot(X_new, y_new, "r-", linewidth=2, label=" New Predictions")
plt.plot(X_train, y_train, "b.",label='Training points')
plt.plot(X_test, y_test, "g.",label='Testing points')
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# %% [markdown]
# ## Pipeline Concepts

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.preprocessing import PolynomialFeatures

def poly_regression(degree):
    X_new = np.linspace(-3, 3, 200).reshape(200, 1)
    
    poly_features=PolynomialFeatures(degree=degree,include_bias=True)
    lin_reg=LinearRegression()
    poly_regression=Pipeline([
        ("poly_features",poly_features),
        ("lin_reg",lin_reg)
    ])
    poly_regression.fit(X_train,y_train) ## ploynomial and fit of linear reression
    y_pred_new=poly_regression.predict(X_new)
    #plotting prediction line
    plt.plot(X_new, y_pred_new,'r', label="Degree " + str(degree), linewidth=2)
    plt.plot(X_train, y_train, "b.", linewidth=3)
    plt.plot(X_test, y_test, "g.", linewidth=3)
    plt.legend(loc="upper left")
    plt.xlabel("X")
    plt.ylabel("y")
    plt.axis([-4,4, 0, 10])
    plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.preprocessing import PolynomialFeatures
# from sklearn.linear_model import LinearRegression
# from sklearn.pipeline import Pipeline

# def poly_regression(X_train, y_train, X_test, y_test, degree):
#     # Generate new X values for smooth curve
#     X_new = np.linspace(-3, 3, 200).reshape(-1, 1)
    
#     # Build pipeline: Polynomial + Linear Regression
#     model = Pipeline([
#         ("poly_features", PolynomialFeatures(degree=degree, include_bias=True)),
#         ("lin_reg", LinearRegression())
#     ])
    
#     # Train the model
#     model.fit(X_train, y_train)
    
#     # Predict for smooth curve
#     y_pred_new = model.predict(X_new)
    
#     # Visualization
#     plt.figure(figsize=(8, 5))
#     plt.plot(X_new, y_pred_new, 'r', label=f"Degree {degree}", linewidth=2)
#     plt.scatter(X_train, y_train, color='blue', label='Train Data')
#     plt.scatter(X_test, y_test, color='green', label='Test Data')
#     plt.legend(loc="upper left")
#     plt.xlabel("X")
#     plt.ylabel("y")
#     plt.title(f"Polynomial Regression (Degree = {degree})")
#     plt.axis([-4, 4, 0, 10])
#     plt.grid(True, linestyle='--', alpha=0.6)
#     plt.show()

# %%
poly_regression(6)
