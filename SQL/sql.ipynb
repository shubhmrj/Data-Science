# %%
# !pip install psycopg2-binary pandas
# Out:
# ...
#   Using cached psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# ...
# Using cached psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl (2.7 MB)
# ...

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:Shubham%403166@localhost:5433/postgres

# %%
# %sql SELECT current_database(), current_user
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 1 rows affected.
# [('postgres', 'postgres')]

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# !psql -U postgres -d postgres -c "\copy superstore_orders FROM 'E:/Data Science/SQL/SuperStoreOrders - SuperStoreOrders.csv' DELIMITER ',' CSV HEADER;"
# Out:
# 'psql' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %%sql
# CREATE TABLE superstore_orders (
#     order_id TEXT,
#     order_date DATE,
#     ship_date DATE,
#     ship_mode TEXT,
#     customer_name TEXT,
#     segment TEXT,
#     country TEXT,
#     city TEXT,
#     state TEXT,
#     country TEXT,
#     region TEXT,
#     product_id TEXT,
#     category TEXT,
#     sub_category TEXT,
#     product_name TEXT,
#     sales FLOAT,
#     quantity INT,
#     discount FLOAT,
#     profit FLOAT
# );
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# Done.
# []

# %%
import pandas as pd
pd.read_csv("SuperStoreOrders - SuperStoreOrders.csv")
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31/12/2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31/12/2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31/12/2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31/12/2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31/12/2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
# %%sql
# COPY superstore_orders
# FROM 'E:/Data Science/SQL/SuperStoreOrders - SuperStoreOrders.csv'
# DELIMITER ','
# CSV HEADER;
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# (psycopg2.errors.UndefinedTable) relation "superstore_orders" does not exist
#
# [SQL: COPY superstore_orders
# FROM 'E:/Data Science/SQL/SuperStoreOrders - SuperStoreOrders.csv'
# DELIMITER ','
# CSV HEADER;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# COPY superstore_orders
# FROM 'E:/Data Science/SQL/SuperStoreOrders - SuperStoreOrders.csv'
# DELIMITER ','
# CSV HEADER;
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# (psycopg2.errors.BadCopyFileFormat) extra data after last expected column
# CONTEXT:  COPY superstore_orders, line 2: "AG-2011-2040,1/1/2011,6/1/2011,Standard Class,Toby Braunhardt,Consumer,Constantine,Algeria,Africa,Af..."
#
# [SQL: COPY superstore_orders
# FROM 'E:/Data Science/SQL/SuperStoreOrders - SuperStoreOrders.csv'
# DELIMITER ','
# CSV HEADER;]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
