# %%
import numpy as np

# %%
# Logical OPeration

data=np.array([1,2,3,4,66,8,85])

data[(data>=5) & (data<=8)]
# Out:
# array([8])

# %%
import pandas as pd
import numpy as np

def import_dataset(filepath: str) -> pd.DataFrame:
    try:
        df = pd.read_csv(filepath)
        print("Dataset imported successfully.")
        return df
    except Exception as e:
        print(f"Error importing dataset: {e}")
        raise

def clean_data(df: pd.DataFrame) -> pd.DataFrame:
    df_cleaned = df.drop_duplicates()
    df_cleaned = df_cleaned.fillna(method='ffill')  
    print("Data cleaned successfully.")
    return df_cleaned

def manipulate_data_with_numpy(df: pd.DataFrame) -> pd.DataFrame:
    
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    df[numeric_cols] = (df[numeric_cols] - np.min(df[numeric_cols])) / (np.max(df[numeric_cols]) - np.min(df[numeric_cols]))
    print("Dataframe manipulated successfully using NumPy.")
    return df

def main():
    filepath = 'google_cleaned.csv'
    df = import_dataset(filepath)
    df = clean_data(df)
    df = manipulate_data_with_numpy(df)
    print(df.head())

if __name__ == "__main__":
     main()
# Out:
# Dataset imported successfully.
# Data cleaned successfully.
# Dataframe manipulated successfully using NumPy.
#      Unnamed: 0                                                App  \
# 0  0.000000e+00     Photo Editor & Candy Camera & Grid & ScrapBook
# 1  1.000000e-09                                Coloring book moana
# 2  2.000000e-09  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3  3.000000e-09                              Sketch - Draw & Paint
# 4  4.000000e-09              Pixel Draw - Number Art Coloring Book
#
#          Category        Rating       Reviews          Size  Installs  Type  \
# 0  ART_AND_DESIGN  4.100000e-09  1.590000e-07  1.900000e-05   0.00001  Free
# 1  ART_AND_DESIGN  3.900000e-09  9.670000e-07  1.400000e-05   0.00050  Free
# 2  ART_AND_DESIGN  4.700000e-09  8.751000e-05  8.700000e-09   0.00500  Free
# 3  ART_AND_DESIGN  4.500000e-09  2.156440e-04  2.500000e-05   0.05000  Free
# 4  ART_AND_DESIGN  4.300000e-09  9.670000e-07  2.800000e-09   0.00010  Free
#
#    Price Content Rating                     Genres Last Updated  \
# 0    0.0       Everyone               Art & Design   2018-01-07
# 1    0.0       Everyone  Art & Design;Pretend Play   2018-01-15
# 2    0.0       Everyone               Art & Design   2018-08-01
# 3    0.0           Teen               Art & Design   2018-06-08
# 4    0.0       Everyone    Art & Design;Creativity   2018-06-20
#
#           Current Ver   Android Ver           Day         Month      Year
# 0               1.0.0  4.0.3 and up  7.000000e-09  1.000000e-09  0.000002
# 1               2.0.0  4.0.3 and up  1.500000e-08  1.000000e-09  0.000002
# 2               1.2.4  4.0.3 and up  1.000000e-09  8.000000e-09  0.000002
# 3  Varies with device    4.2 and up  8.000000e-09  6.000000e-09  0.000002
# 4                 1.1    4.4 and up  2.000000e-08  6.000000e-09  0.000002
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8368\2846167040.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df_cleaned.fillna(method='ffill')

# %%
main()
# Out:
# Dataset imported successfully.
# Data cleaned successfully.
# Dataframe manipulated successfully using NumPy.
#      Unnamed: 0                                                App  \
# 0  0.000000e+00     Photo Editor & Candy Camera & Grid & ScrapBook
# 1  1.000000e-09                                Coloring book moana
# 2  2.000000e-09  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3  3.000000e-09                              Sketch - Draw & Paint
# 4  4.000000e-09              Pixel Draw - Number Art Coloring Book
#
#          Category        Rating       Reviews          Size  Installs  Type  \
# 0  ART_AND_DESIGN  4.100000e-09  1.590000e-07  1.900000e-05   0.00001  Free
# 1  ART_AND_DESIGN  3.900000e-09  9.670000e-07  1.400000e-05   0.00050  Free
# 2  ART_AND_DESIGN  4.700000e-09  8.751000e-05  8.700000e-09   0.00500  Free
# 3  ART_AND_DESIGN  4.500000e-09  2.156440e-04  2.500000e-05   0.05000  Free
# 4  ART_AND_DESIGN  4.300000e-09  9.670000e-07  2.800000e-09   0.00010  Free
#
#    Price Content Rating                     Genres Last Updated  \
# 0    0.0       Everyone               Art & Design   2018-01-07
# 1    0.0       Everyone  Art & Design;Pretend Play   2018-01-15
# 2    0.0       Everyone               Art & Design   2018-08-01
# 3    0.0           Teen               Art & Design   2018-06-08
# 4    0.0       Everyone    Art & Design;Creativity   2018-06-20
#
#           Current Ver   Android Ver           Day         Month      Year
# 0               1.0.0  4.0.3 and up  7.000000e-09  1.000000e-09  0.000002
# 1               2.0.0  4.0.3 and up  1.500000e-08  1.000000e-09  0.000002
# 2               1.2.4  4.0.3 and up  1.000000e-09  8.000000e-09  0.000002
# 3  Varies with device    4.2 and up  8.000000e-09  6.000000e-09  0.000002
# 4                 1.1    4.4 and up  2.000000e-08  6.000000e-09  0.000002
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8368\2846167040.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df_cleaned.fillna(method='ffill')
