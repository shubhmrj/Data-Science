# %%
import sqlite3 as db

# %%
# connect to database

connection = db.connect('sql.db')

# %%
# create a cursor to iterate the table

cursor = connection.cursor()

# %%
# create a table

cursor.execute('''
              CREATE TABLE IF NOT EXISTS users(
                  id INTEGER PRIMARY KEY,
                  name TEXT not null,
                  age INTEGER,
                  email UNIQUE
              ) 
''')

connection.commit()

# %%
# intertion

cursor.execute(
    "INSERT INTO users (id,name,age,email) VALUES(?,?, ?, ?)",(1,'SHUBHAM',23,'SRNWDA')
)
connection.commit()
