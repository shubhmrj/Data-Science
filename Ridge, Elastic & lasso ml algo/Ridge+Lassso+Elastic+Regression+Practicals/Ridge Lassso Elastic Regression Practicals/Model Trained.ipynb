# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Algerian_forest_fires_cleaned_dataset.csv')

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
# drop unecessary columns
# if you run again this , this line gives error because you delete column 
df.drop(['day','month','year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df["Classes"].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df['Classes']= np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
# df['Classes'] = np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
##independent and dependent features
x= df.drop('FWI',axis=1)
y= df['FWI']

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
Y.head()
# Out:
# 0    0.5
# 1    0.4
# 2    0.1
# 3    0.0
# 4    0.5
# Name: FWI, dtype: float64

# %%
Y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
df.iloc("temperature")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'temperature'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13900\878217893.py in ?()
# ----> 1 df.iloc("temperature")
#
# c:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
# ...

# %%
df.rename(columns={'Temperature':'Temperatures'},inplace=True)
# Out:
#      Temperatures  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0              29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1              29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2              26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3              25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4              27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..            ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238            30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239            28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240            27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241            24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242            24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
df.rename(columns={'Temperatures':'Temperature'},inplace=True)

# %%
df.describe()
# Out:
#        Temperature          RH          Ws        Rain        FFMC  \
# count   243.000000  243.000000  243.000000  243.000000  243.000000
# mean     32.152263   62.041152   15.493827    0.762963   77.842387
# std       3.628039   14.828160    2.811385    2.003207   14.349641
# min      22.000000   21.000000    6.000000    0.000000   28.600000
# 25%      30.000000   52.500000   14.000000    0.000000   71.850000
# 50%      32.000000   63.000000   15.000000    0.000000   83.300000
# 75%      35.000000   73.500000   17.000000    0.500000   88.300000
# max      42.000000   90.000000   29.000000   16.800000   96.000000
#
#               DMC          DC         ISI         BUI         FWI     Classes  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean    14.680658   49.430864    4.742387   16.690535    7.035391    0.563786
# std     12.393040   47.665606    4.154234   14.228421    7.440568    0.496938
# ...

# %%
df.loc[0,'Temperature']=30

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           30  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df.loc[0,'Temperature']=29

# %%
df.head(2)
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4  7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1  7.6  1.0  3.9  0.4        0       0

# %%
# train test split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
X_train.head()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI   BUI  Classes  Region
# 97            29  74  19   0.1  75.8   3.6  32.2   2.1   5.6        0       0
# 141           31  72  14   0.2  60.2   3.8   8.0   0.8   3.7        0       1
# 192           40  31  15   0.0  94.2  22.5  46.3  16.6  22.4        1       1
# 68            32  60  18   0.3  77.1  11.3  47.0   2.2  14.1        0       0
# 119           32  47  14   0.7  77.5   7.1   8.8   1.8   6.8        0       0

# %%
X_test.head()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  Region
# 24            31  64  15   0.0  86.7  14.2  63.8  5.7  18.3        1       0
# 6             33  54  13   0.0  88.2   9.9  30.5  6.4  10.9        1       0
# 152           28  58  18   2.2  63.7   3.2   8.5  1.2   3.3        0       1
# 232           34  58  13   0.2  79.5  18.7  88.0  2.1  24.4        0       1
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9        1       1

# %%
y_train.head()
# Out:
# 97      0.9
# 141     0.3
# 192    21.6
# 68      2.6
# 119     0.9
# Name: FWI, dtype: float64

# %%
y_test.head()
# Out:
# 24     8.4
# 6      7.2
# 152    0.5
# 232    3.8
# 238    6.5
# Name: FWI, dtype: float64

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# ...
