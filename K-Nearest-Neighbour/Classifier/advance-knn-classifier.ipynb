# %%
import os

for dirname, _, filenames in os.walk("Classifier"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        path = os.path.join(dirname, filename)
        print(path)

# %%
import pandas as pd
data = pd.read_csv("KNNAlgorithmDataset.csv")
